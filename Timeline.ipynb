# %% [markdown]
# # XPN 2020
#
# After taking a year off from playlists, they are back.
# This time instead of an A-Z walk though their catalog
# [WXPN](https://www.xpn.org) is back to listener curated lists
# with this years [2002 Countdown](https://xpn.org/music-artist/885-countdown/2020/).
# This time the station is doing their own stats page,
# [2020 Countdown, by the Numbers](https://thekey.xpn.org/wxpn-2020-numbers/).
# But for fun, I'll still do something.

# %%
# %matplotlib inline
from IPython.display import display, HTML

# %% [markdown]
# ## Status
#
# It's Saturday morning.
# The it's day 3 of the countdown, which wil probably only run a week.
# [WXPN](https://xpn.org) had done a great job of doing their own stats.
# Checkout the thier stuff at [XPN 2020, by the numbers](https://thekey.xpn.org/wxpn-2020-numbers/).
# I'll keep re-running this to kep the data up.
# But I'm going to try to find some interesting insights to drill down on to add value,
# since the station has the basics like "which artists are playing the most" covered.
#
# * Add comparision with 2014's 885 best and 88 worst
# * make joins to best and worst case insensitive, so ABBA matches Abba.  Thanks to [Joe Lynch](https://twitter.com/jwlynchjr) for catching that.

# %% [markdown]
# ## Loading the Data
#
# Most people are probably not too interested in how I pull the data, clean it and augment it.
# If you do the details are in my [Data Loading notebook](DataLoading.ipynb).
# If you want a copy of the raw data to play with yourself,
# feel free to look at [xpn2020.csv](./data/xpn2020.csv).
# If you do something interesting with the data,
# please let me know.
# And tell the station and post to [twitter](https://twitter.com) with the hash tag `#XPN2020`.
# I'm sure other listeners will be glad to see what you have done.

# %%
import pandas as pd
from datetime import date, datetime, time, timedelta
from os import path
data_dir = './data'
playlist_file = path.join(data_dir, 'xpn2020.csv')
playlist = pd.read_csv(playlist_file)

playlist['Air Time'] = pd.to_datetime(playlist['Air Time'], errors='coerce')
last_play = playlist.loc[playlist['Air Time'].idxmax()]
end_time = last_play['Air Time'] + timedelta(seconds = 60 * last_play['Duration'])
HTML('<p>So far, as of %s, we have seen %d tracks with %d unique titles, from %d artists.</p>' %\
    (end_time.strftime('%b %d %I:%M%p'),
     len(playlist),
     playlist.describe(include='all')['Title']['unique'], 
     playlist.describe(include='all')['Artist']['unique']
     ))
# Out:
# <p>So far, as of Dec 12 06:17PM, we have seen 734 tracks with 728 unique titles, from 444 artists.</p>

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Most Popular Artists
#
# It's always interesting to see which artists show up the most.
# There tends to be bias to nostalgia.
# But there's usually some new stuff mixed in.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Comparision with other XPN Playlists

# %% [markdown]
# #### 885 Best and 88 Worst
#
# Back in 2014 there was a very similar [885 All Time Greatest Song](https://xpn.org/music-artist/885-countdown/2014/885-countdown-2014) countdown.
# While this countdown has almost 3 times as many songs,
# it might be interesting to see how they compare.

# %%
def overlapping_songs(list1, list2):
    list1a = list1.copy()
    list2a = list2.copy()
    list1a['Title_lc'] = list1a['Title'].str.lower()
    list1a['Artist_lc'] = list1a['Artist'].str.lower()
    list2a['Title_lc'] = list2a['Title'].str.lower()
    list2a['Artist_lc'] = list2a['Artist'].str.lower()
    intersect = pd.merge(list1a, list2a, how='inner', on=['Title_lc', 'Artist_lc'])
    intersect.drop(intersect.columns.difference(['Title_x','Artist_x']), 1, inplace=True)
    intersect.columns = ['Artist', 'Title']
    return intersect

    
best885_file = path.join(data_dir, '885best.csv')
best885 = pd.read_csv(best885_file)
besties = overlapping_songs(playlist, best885)
besties.to_csv(path.join(data_dir, 'XPN2020_and_885Best.csv'), index=False)


worst88_file = path.join(data_dir, '88worst.csv')
worst88 = pd.read_csv(worst88_file)
horrors = overlapping_songs(playlist, worst88)
horrors.to_csv(path.join(data_dir, 'XPN2020_and_88Worst.csv'), index=False)

s= "<p>Of the %d tracks in the 2020 Countdown so far, " + \
    "%d or %0.2f%% where in 2014's 885 best playlist. " + \
    "Those are available as <a href='data/XPN2020_and_885Best.csv'>XPN2020_and_885Best.csv</a>. " + \
    "Sadly %d were in 2014's 88 worst playlist. " + \
    "Those are available as <a href='data/XPN2020_and_88Worst.csv'>XPN2020_and_88Worst.csv</a>.</p>"
HTML(s %(len(playlist), len(besties), float(len(besties) * 100) / float(len(playlist)),
         len(horrors)))
# Out:
# <p>Of the 734 tracks in the 2020 Countdown so far, 60 or 8.17% where in 2014's 885 best playlist. Those are available as <a href='data/XPN2020_and_885Best.csv'>XPN2020_and_885Best.csv</a>. Sadly 4 were in 2014's 88 worst playlist. Those are available as <a href='data/XPN2020_and_88Worst.csv'>XPN2020_and_88Worst.csv</a>.</p>

# %% [markdown]
# It's odd to be seeing so many of the 885 best already,
# as we're not even in the top 1000, so they have dropped a bit.

# %% [markdown]
# And what were those worst songs that were apparently someone's favorites?

# %% [markdown]
# ####  How the Tracks changed place

# %%
best885.insert(0, 'Rank', range(1, 1 + len(best885)))
HTML(best885.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Title</th>
#       <th>Artist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Thunder Road</td>
#       <td>Bruce Springsteen</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Like A Rolling Stone</td>
#       <td>Bob Dylan</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Imagine</td>
#       <td>John Lennon</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>A Day In The Life</td>
#       <td>The Beatles</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Born To Run</td>
#       <td>Bruce Springsteen</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>Stairway To Heaven</td>
#       <td>Led Zeppelin</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>Gimme Shelter</td>
#       <td>The Rolling Stones</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>Layla</td>
#       <td>Derek And The Dominoes</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>Sympathy For The Devil</td>
#       <td>The Rolling Stones</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>Hey Jude</td>
#       <td>The Beatles</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>Bohemian Rhapsody</td>
#       <td>Queen</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>In My Life</td>
#       <td>The Beatles</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>Into The Mystic</td>
#       <td>Van Morrison</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td>Tangled Up In Blue</td>
#       <td>Bob Dylan</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>Jungleland</td>
#       <td>Bruce Springsteen</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td>The Weight</td>
#       <td>The Band</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>17</td>
#       <td>Hallelujah</td>
#       <td>Jeff Buckley</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>18</td>
#       <td>Let It Be</td>
#       <td>The Beatles</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>19</td>
#       <td>Satisfaction</td>
#       <td>The Rolling Stones</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>20</td>
#       <td>All Along The Watchtower</td>
#       <td>Jimi Hendrix</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>21</td>
#       <td>Baba O'Reilly</td>
#       <td>The Who</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>22</td>
#       <td>God Only Knows</td>
#       <td>The Beach Boys</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>23</td>
#       <td>Comfortably Numb</td>
#       <td>Pink Floyd</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>24</td>
#       <td>Wish You Were Here</td>
#       <td>Pink Floyd</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>25</td>
#       <td>One</td>
#       <td>U2</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>26</td>
#       <td>Hallelujah</td>
#       <td>Leonard Cohen</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>27</td>
#       <td>Rosalita</td>
#       <td>Bruce Springsteen</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>28</td>
#       <td>Bridge Over Troubled Water</td>
#       <td>Simon &amp; Garfunkel</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>29</td>
#       <td>Kashmir</td>
#       <td>Led Zeppelin</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>30</td>
#       <td>Won't Get Fooled Again</td>
#       <td>The Who</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>31</td>
#       <td>Smells Like Teen Spirit</td>
#       <td>Nirvana</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>32</td>
#       <td>Hotel California</td>
#       <td>The Eagles</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>33</td>
#       <td>London Calling</td>
#       <td>The Clash</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>34</td>
#       <td>Impossible Germany</td>
#       <td>Wilco</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>35</td>
#       <td>This Must Be The Place</td>
#       <td>The Talking Heads</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>36</td>
#       <td>At Last</td>
#       <td>Etta James</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>37</td>
#       <td>Here Comes The Sun</td>
#       <td>The Beatles</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>38</td>
#       <td>A Little Bit Of Everything</td>
#       <td>Dawes</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>39</td>
#       <td>One Big Holiday</td>
#       <td>My Morning Jacket</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>40</td>
#       <td>While My Guitar Gently Weeps</td>
#       <td>The Beatles</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>41</td>
#       <td>1952 Vincent Black Lightning</td>
#       <td>Richard Thompson</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>42</td>
#       <td>What's Going On</td>
#       <td>Marvin Gaye</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>43</td>
#       <td>Suite Judy Blue Eyes</td>
#       <td>Crosby Stills &amp; Nash</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>44</td>
#       <td>Good Vibrations</td>
#       <td>The Beach Boys</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>45</td>
#       <td>(Sittin' On) The Dock Of The Bay</td>
#       <td>Otis Redding</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>46</td>
#       <td>Rolllin In The Deep</td>
#       <td>Adele</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>47</td>
#       <td>What A Wonderful World</td>
#       <td>Louis Armstrong</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>48</td>
#       <td>Can't You Hear Me Knocking</td>
#       <td>The Rolling Stones</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>49</td>
#       <td>Low Spark Of High Heeled Boys</td>
#       <td>Traffic</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>50</td>
#       <td>Moondance</td>
#       <td>Van Morrison</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>51</td>
#       <td>You Can't Always Get Want You Want</td>
#       <td>The Rolling Stones</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>52</td>
#       <td>Heroes</td>
#       <td>David Bowie</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>53</td>
#       <td>Under Pressure</td>
#       <td>Queen</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>54</td>
#       <td>When My Time Comes</td>
#       <td>Dawes</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>55</td>
#       <td>Johnny B Goode</td>
#       <td>Chuck Berry</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>56</td>
#       <td>Voodoo Child</td>
#       <td>Jimi Hendrix</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>57</td>
#       <td>Respect</td>
#       <td>Aretha Franklin</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>58</td>
#       <td>Wake Up</td>
#       <td>Arcade Fire</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>59</td>
#       <td>Yesterday</td>
#       <td>The Beatles</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>60</td>
#       <td>Waterloo Sunset</td>
#       <td>The Kinks</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>61</td>
#       <td>A Case Of You</td>
#       <td>Joni Mitchell</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>62</td>
#       <td>Abbey Road Medley</td>
#       <td>The Beatles</td>
#     </tr>
#     <tr>
#       <th>62</th>
#       <td>63</td>
#       <td>Harvest Moon</td>
#       <td>Neil Young</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>64</td>
#       <td>Wild Horse</td>
#       <td>The Rolling Stones</td>
#     </tr>
#     <tr>
#       <th>64</th>
#       <td>65</td>
#       <td>Paranoid Andriod</td>
#       <td>Radiohead</td>
#     </tr>
#     <tr>
#       <th>65</th>
#       <td>66</td>
#       <td>Home</td>
#       <td>Edward Sharpe And The Magnetic Zeros</td>
#     </tr>
#     <tr>
#       <th>66</th>
#       <td>67</td>
#       <td>Shine On You Crazy Diamond (I-V)</td>
#       <td>Pink Floyd</td>
#     </tr>
#     <tr>
#       <th>67</th>
#       <td>68</td>
#       <td>Once In A Lifetime</td>
#       <td>The Talking Heads</td>
#     </tr>

# %%
#playlist.insert(0, 'Rank', range(2020, 2020 - len(playlist), -1))
#HTML(playlist.to_html(columns=['Rank', 'Title', 'Artist']))
HTML(playlist.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank</th>
#       <th>Artist</th>
#       <th>Title</th>
#       <th>Air Time</th>
#       <th>Letter</th>
#       <th>First Word</th>
#       <th>Duration</th>
#       <th>Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020</td>
#       <td>Booker T. &amp; The MG's</td>
#       <td>Time Is Tight</td>
#       <td>2020-12-10 08:02:00</td>
#       <td>T</td>
#       <td>Time</td>
#       <td>3</td>
#       <td>1980</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2019</td>
#       <td>AC/DC</td>
#       <td>T.N.T.</td>
#       <td>2020-12-10 08:05:00</td>
#       <td>T</td>
#       <td>T</td>
#       <td>6</td>
#       <td>1975</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2018</td>
#       <td>Peter Frampton</td>
#       <td>Show Me the Way</td>
#       <td>2020-12-10 08:11:00</td>
#       <td>S</td>
#       <td>Show</td>
#       <td>5</td>
#       <td>1975</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2017</td>
#       <td>The Drifters</td>
#       <td>Under The Boardwalk</td>
#       <td>2020-12-10 08:16:00</td>
#       <td>U</td>
#       <td>Under</td>
#       <td>3</td>
#       <td>1989</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2016</td>
#       <td>Adele</td>
#       <td>Rumor Has It</td>
#       <td>2020-12-10 08:19:00</td>
#       <td>R</td>
#       <td>Rumor</td>
#       <td>5</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2015</td>
#       <td>Smith</td>
#       <td>Baby It's You</td>
#       <td>2020-12-10 08:24:00</td>
#       <td>B</td>
#       <td>Baby</td>
#       <td>4</td>
#       <td>1969</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2014</td>
#       <td>Aretha Franklin</td>
#       <td>Call Me</td>
#       <td>2020-12-10 08:28:00</td>
#       <td>C</td>
#       <td>Call</td>
#       <td>3</td>
#       <td>1970</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2013</td>
#       <td>Marvin Gaye &amp; Kim Weston</td>
#       <td>It Takes Two</td>
#       <td>2020-12-10 08:31:00</td>
#       <td>I</td>
#       <td>It</td>
#       <td>3</td>
#       <td>1966</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2012</td>
#       <td>Curtis Mayfield</td>
#       <td>Superfly</td>
#       <td>2020-12-10 08:34:00</td>
#       <td>S</td>
#       <td>Superfly</td>
#       <td>7</td>
#       <td>1973</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2011</td>
#       <td>Shawn Colvin</td>
#       <td>I Don't Know Why</td>
#       <td>2020-12-10 08:41:00</td>
#       <td>I</td>
#       <td>I</td>
#       <td>4</td>
#       <td>1992</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2010</td>
#       <td>Bob Marley &amp; The Wailers</td>
#       <td>Positive Vibration</td>
#       <td>2020-12-10 08:45:00</td>
#       <td>P</td>
#       <td>Positive</td>
#       <td>5</td>
#       <td>1976</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2009</td>
#       <td>Sly &amp; The Family Stone</td>
#       <td>Everybody Is A Star</td>
#       <td>2020-12-10 08:50:00</td>
#       <td>E</td>
#       <td>Everybody</td>
#       <td>4</td>
#       <td>1969</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2008</td>
#       <td>Eric Clapton</td>
#       <td>Blues Power</td>
#       <td>2020-12-10 08:54:00</td>
#       <td>B</td>
#       <td>Blues</td>
#       <td>2</td>
#       <td>1970</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>2007</td>
#       <td>Sharon Jones And The Dap-Kings</td>
#       <td>This Land Is Your Land</td>
#       <td>2020-12-10 08:56:00</td>
#       <td>T</td>
#       <td>This</td>
#       <td>5</td>
#       <td>2005</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>2006</td>
#       <td>The Replacements</td>
#       <td>Androgynous</td>
#       <td>2020-12-10 09:01:00</td>
#       <td>A</td>
#       <td>Androgynous</td>
#       <td>6</td>
#       <td>1984</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2005</td>
#       <td>Grand Funk Railroad</td>
#       <td>I'm Your Captain</td>
#       <td>2020-12-10 09:07:00</td>
#       <td>I</td>
#       <td>I'm</td>
#       <td>9</td>
#       <td>1970</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>2004</td>
#       <td>The Records</td>
#       <td>Starry Eyes</td>
#       <td>2020-12-10 09:16:00</td>
#       <td>S</td>
#       <td>Starry</td>
#       <td>4</td>
#       <td>1978</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>2003</td>
#       <td>Lenny Kravitz</td>
#       <td>Let Love Rule</td>
#       <td>2020-12-10 09:20:00</td>
#       <td>L</td>
#       <td>Let</td>
#       <td>7</td>
#       <td>1989</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>2002</td>
#       <td>Prince</td>
#       <td>1999</td>
#       <td>2020-12-10 09:27:00</td>
#       <td>1</td>
#       <td>1999</td>
#       <td>4</td>
#       <td>1982</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>2001</td>
#       <td>Bonnie Raitt</td>
#       <td>I Know</td>
#       <td>2020-12-10 09:31:00</td>
#       <td>I</td>
#       <td>I</td>
#       <td>3</td>
#       <td>1972</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>2000</td>
#       <td>Roxy Music</td>
#       <td>In Every Dream Home A Heartache</td>
#       <td>2020-12-10 09:34:00</td>
#       <td>I</td>
#       <td>In</td>
#       <td>6</td>
#       <td>1973</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>1999</td>
#       <td>Hall &amp; Oates</td>
#       <td>Fall In Philadelphia</td>
#       <td>2020-12-10 09:40:00</td>
#       <td>F</td>
#       <td>Fall</td>
#       <td>5</td>
#       <td>1996</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>1998</td>
#       <td>James Brown</td>
#       <td>The Payback</td>
#       <td>2020-12-10 09:45:00</td>
#       <td>T</td>
#       <td>The</td>
#       <td>7</td>
#       <td>1973</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>1997</td>
#       <td>Timmy Thomas</td>
#       <td>Why Can't We Live Together</td>
#       <td>2020-12-10 09:52:00</td>
#       <td>W</td>
#       <td>Why</td>
#       <td>6</td>
#       <td>1972</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>1996</td>
#       <td>Jackie DeShannon</td>
#       <td>What The World Needs Now</td>
#       <td>2020-12-10 09:58:00</td>
#       <td>W</td>
#       <td>What</td>
#       <td>3</td>
#       <td>1988</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>1995</td>
#       <td>Aretha Franklin</td>
#       <td>Amazing Grace</td>
#       <td>2020-12-10 10:01:00</td>
#       <td>A</td>
#       <td>Amazing</td>
#       <td>17</td>
#       <td>1972</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>1994</td>
#       <td>The Band</td>
#       <td>Whispering Pines</td>
#       <td>2020-12-10 10:18:00</td>
#       <td>W</td>
#       <td>Whispering</td>
#       <td>4</td>
#       <td>1969</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>1993</td>
#       <td>The Eagles</td>
#       <td>Life In The Fast Lane</td>
#       <td>2020-12-10 10:22:00</td>
#       <td>L</td>
#       <td>Life</td>
#       <td>5</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>1992</td>
#       <td>The Eagles</td>
#       <td>New Kid In Town</td>
#       <td>2020-12-10 10:27:00</td>
#       <td>N</td>
#       <td>New</td>
#       <td>6</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>1991</td>
#       <td>Creedence Clearwater Revival</td>
#       <td>Down On The Corner</td>
#       <td>2020-12-10 10:33:00</td>
#       <td>D</td>
#       <td>Down</td>
#       <td>2</td>
#       <td>1969</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>1990</td>
#       <td>Al Green</td>
#       <td>I'm Still In Love With You</td>
#       <td>2020-12-10 10:35:00</td>
#       <td>I</td>
#       <td>I'm</td>
#       <td>3</td>
#       <td>1972</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>1989</td>
#       <td>Carole King</td>
#       <td>You've Got A Friend</td>
#       <td>2020-12-10 10:38:00</td>
#       <td>Y</td>
#       <td>You've</td>
#       <td>7</td>
#       <td>1971</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>1988</td>
#       <td>War</td>
#       <td>Me And Baby Brother</td>
#       <td>2020-12-10 10:45:00</td>
#       <td>M</td>
#       <td>Me</td>
#       <td>3</td>
#       <td>1973</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>1987</td>
#       <td>Tom Rush</td>
#       <td>No Regrets</td>
#       <td>2020-12-10 10:48:00</td>
#       <td>N</td>
#       <td>No</td>
#       <td>4</td>

# %%
best885['Title_lc'] = best885['Title'].str.lower().str.translate(None, string.punctuation).str.translate(None, string.whitespace)
best885['Artist_lc'] = best885['Artist'].str.lower().str.translate(None, string.punctuation).str.translate(None, string.whitespace)

xpn2020 = playlist.copy()
xpn2020.drop(xpn2020.columns.difference(['Rank', 'Title', 'Artist']), 1, inplace=True) 
xpn2020['Title'] = xpn2020['Title'].str.lower().str.translate(None, string.punctuation).str.translate(None, string.whitespace)
xpn2020['Artist'] = xpn2020['Artist'].str.lower().str.translate(None, string.punctuation).str.translate(None, string.whitespace)
xpn2020.columns = ['Rank', 'Artist_lc', 'Title_lc']
composite = pd.merge(best885, xpn2020, how='left', on=['Title_lc', 'Artist_lc'], suffixes=['_885', '_2020'])
composite.drop(['Title_lc', 'Artist_lc'], 1, inplace=True)
composite['Change'] = composite['Rank_885'] - composite['Rank_2020']
HTML(composite.to_html())
#HTML(xpn2020.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Rank_885</th>
#       <th>Title</th>
#       <th>Artist</th>
#       <th>Rank_2020</th>
#       <th>Change</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Thunder Road</td>
#       <td>Bruce Springsteen</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Like A Rolling Stone</td>
#       <td>Bob Dylan</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>Imagine</td>
#       <td>John Lennon</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>A Day In The Life</td>
#       <td>The Beatles</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>Born To Run</td>
#       <td>Bruce Springsteen</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>Stairway To Heaven</td>
#       <td>Led Zeppelin</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>7</td>
#       <td>Gimme Shelter</td>
#       <td>The Rolling Stones</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>8</td>
#       <td>Layla</td>
#       <td>Derek And The Dominoes</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>9</td>
#       <td>Sympathy For The Devil</td>
#       <td>The Rolling Stones</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>10</td>
#       <td>Hey Jude</td>
#       <td>The Beatles</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>11</td>
#       <td>Bohemian Rhapsody</td>
#       <td>Queen</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>12</td>
#       <td>In My Life</td>
#       <td>The Beatles</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>13</td>
#       <td>Into The Mystic</td>
#       <td>Van Morrison</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>14</td>
#       <td>Tangled Up In Blue</td>
#       <td>Bob Dylan</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>15</td>
#       <td>Jungleland</td>
#       <td>Bruce Springsteen</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>16</td>
#       <td>The Weight</td>
#       <td>The Band</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>17</td>
#       <td>Hallelujah</td>
#       <td>Jeff Buckley</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>18</td>
#       <td>Let It Be</td>
#       <td>The Beatles</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>19</td>
#       <td>Satisfaction</td>
#       <td>The Rolling Stones</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>20</td>
#       <td>All Along The Watchtower</td>
#       <td>Jimi Hendrix</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>21</td>
#       <td>Baba O'Reilly</td>
#       <td>The Who</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>22</td>
#       <td>God Only Knows</td>
#       <td>The Beach Boys</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>23</td>
#       <td>Comfortably Numb</td>
#       <td>Pink Floyd</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>24</td>
#       <td>Wish You Were Here</td>
#       <td>Pink Floyd</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>25</td>
#       <td>One</td>
#       <td>U2</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>26</td>
#       <td>Hallelujah</td>
#       <td>Leonard Cohen</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>27</td>
#       <td>Rosalita</td>
#       <td>Bruce Springsteen</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>28</td>
#       <td>Bridge Over Troubled Water</td>
#       <td>Simon &amp; Garfunkel</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>29</td>
#       <td>Kashmir</td>
#       <td>Led Zeppelin</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>30</td>
#       <td>Won't Get Fooled Again</td>
#       <td>The Who</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>31</td>
#       <td>Smells Like Teen Spirit</td>
#       <td>Nirvana</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>32</td>
#       <td>Hotel California</td>
#       <td>The Eagles</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>33</td>
#       <td>London Calling</td>
#       <td>The Clash</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>34</td>
#       <td>Impossible Germany</td>
#       <td>Wilco</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>35</td>
#       <td>This Must Be The Place</td>
#       <td>The Talking Heads</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>36</td>
#       <td>At Last</td>
#       <td>Etta James</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>37</td>
#       <td>Here Comes The Sun</td>
#       <td>The Beatles</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>38</td>
#       <td>A Little Bit Of Everything</td>
#       <td>Dawes</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>39</td>
#       <td>One Big Holiday</td>
#       <td>My Morning Jacket</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>40</td>
#       <td>While My Guitar Gently Weeps</td>
#       <td>The Beatles</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>41</td>
#       <td>1952 Vincent Black Lightning</td>
#       <td>Richard Thompson</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>42</td>
#       <td>What's Going On</td>
#       <td>Marvin Gaye</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>43</td>
#       <td>Suite Judy Blue Eyes</td>
#       <td>Crosby Stills &amp; Nash</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>44</td>
#       <td>Good Vibrations</td>
#       <td>The Beach Boys</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>45</td>
#       <td>(Sittin' On) The Dock Of The Bay</td>
#       <td>Otis Redding</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>46</td>
#       <td>Rolllin In The Deep</td>
#       <td>Adele</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>47</td>
#       <td>What A Wonderful World</td>
#       <td>Louis Armstrong</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>48</td>
#       <td>Can't You Hear Me Knocking</td>
#       <td>The Rolling Stones</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>49</td>
#       <td>Low Spark Of High Heeled Boys</td>
#       <td>Traffic</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>50</td>
#       <td>Moondance</td>
#       <td>Van Morrison</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>51</td>
#       <td>You Can't Always Get Want You Want</td>
#       <td>The
